# %% [markdown]
# #### 1.	What is a neural network? What are the general steps required to build a neural network?

# %% [markdown]
# ## Neural Networks
#
# ### General idea
# The NN is a algorithm that mimics the human brain to understand patterns in data by creating a series of models and algorithms to do so.
#
# ### Definition
# A Neural network attempts to classify the target variable accurately by determining which input is most helpful in classifying data without error.
#
# ### Structure of a Neural Network
# Composed of layers that are made up of nodes.
#
#     Node: place where computation happens--"perceptron"
#
# - Input Layer = is the input data
#
# - Output Layer = is the prediction
#
# - Hidden Layers: Much of the work and processes take place in the hidden layers. Its not something that is directly observable.
#
# ### How Neural Networks Work
#
# 1. A node takes in multiple variables (features) as input from the data and combines it with a set of coefficients or weights (for the purpose of making predictions)
#
# This particular process can do one of the following:
#
#     - Amplify input
#     - Dampen input
#
# 2. The input-weight combnations are summed
#
# 3. The sum is then passed through the activation function which determines whether or not that "signal" should continue through the network. If it does continue, the activation function determines the extent to which the signal progresses through the neural network. Once the signal passes, the node is “activated.” NOTE: Multiple linear regression (more than one feature affecting the outcome) is happening at every node of a neural network.
#
# - Then each node is compared with other nodes iteratively
#
# 4. Eventually this process leads to the ultimate outcome.
#
#
# Each layer’s output is simultaneously the subsequent layer’s input, starting from an initial input layer receiving your data.

# %% [markdown]
# #### 2.	Generally, how do you check the performance of a neural network? Why?

# %% [markdown]
# ## Loss Function
#
# Loss Functions are used to check the performance of a neural network.
#
# ### What is a Loss Function?
#
# - This is a function that calculates the error of a given set of weights in order to determine the distance between the neural network's current or predicted output and the expected output ot target value.
#
# ### How is the 'loss' from a Loss function used?
#
# 1) The loss is calculated
#
#         - If the deviation between y_pred(predicted output) and y(expected output/target value) is very large,
#           the loss value will be very high.
#         - If the deviation is small or the values are nearly identical, loss value will be low.
#
# 2) LEARNING PROCESS: the loss is used as a feedback signal to adjust the way in which the Nework works
#
#
# ### Types of Loss Functions
#
# There are different types of loss functions to choose from to calculate the loss of the model. But it is important to choose the right one. We have different loss functions because of the different types of models out there--like regression, classification models. This difference is also reflected in the types of loss functions.
#
# PyTorch’s torch.nn module contains the types of loss functions.
#
#
# ### Why the need to check performance?
#
# We need to see if our model is doing a good job in predicting our target variable.

# %% [markdown]
# #### 3.	Create a neural network using keras to predict the outcome of either of these datasets:
# Cardiac Arrhythmia: https://archive.ics.uci.edu/ml/datasets/Arrhythmia
# Abalone age: https://archive.ics.uci.edu/ml/datasets/Abalone

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.metrics import classification_report, plot_confusion_matrix
import pydotplus
from IPython.display import Image


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
arrhythmia_df = pd.read_csv("arrhythmia.data") 
arrhythmia_df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    1     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    1     155      55           93         106          386
# 451   78    1     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ... chV6_QwaveAmp chV6_RwaveAmp chV6_SwaveAmp  \
# 0          174        121  -16  ...           0.0           9.0          -0.9
# 1          149         39   25  ...           0.0           8.5           0.0
# 2          185        102   96  ...           0.0           9.5          -2.4
# 3          179        143   28  ...           0.0          12.2          -2.2
# 4          177        103  -16  ...           0.0          13.1          -3.6
# ..         ...        ...  ...  ...           ...           ...           ...
# 447        154        117  -37  ...           0.0           4.3          -5.0
# 448        201         73   86  ...           0.0          15.6          -1.6
# 449        194        116  -85  ...           0.0          16.3         -28.6
# 450        218         63   54  ...          -0.4          12.0          -0.7
# 451        138         78   28  ...           0.0          10.4          -1.8
#
#     chV6_RPwaveAmp chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# 0              0.0            0.0            0.9            2.9       23.3
# 1              0.0            0.0            0.2            2.1       20.4
# 2              0.0            0.0            0.3            3.4       12.3
# 3              0.0            0.0            0.4            2.6       34.6
# 4              0.0            0.0           -0.1            3.9       25.4
# ..             ...            ...            ...            ...        ...
# 447            0.0            0.0            0.7            0.6       -4.4
# 448            0.0            0.0            0.4            2.4       38.0
# 449            0.0            0.0            1.5            1.0      -44.2
# 450            0.0            0.0            0.5            2.4       25.0
# 451            0.0            0.0            0.5            1.6       21.3
#
#      chV6_QRSTA  class
# 0          49.4      8
# 1          38.8      6
# 2          49.0     10
# 3          61.6      1
# 4          62.8      7
# ..          ...    ...
# 447        -0.5      1
# 448        62.4     10
# 449       -33.2      2
# 450        46.6      1
# 451        32.8      1
#
# [452 rows x 280 columns]

# %% [markdown]
# ## 1) There are no nulls in the dataset!

# %% [markdown]
# ## 2) Two rows are removed below...
#
# ### (In other words, 450 rows are "pulled" into the variable arrhythmia_df, heights --> 22 & 23ft)

# %%
arrhythmia_df = arrhythmia_df.loc[arrhythmia_df['height'] < 274]

# %% [markdown]
# ## 3) '?' Replaced with 'NaN'...

# %%
arrhythmia_df = arrhythmia_df.replace('?', np.nan)

# %%
for i in arrhythmia_df.isnull().sum():
    if i > 0:
        print(i)
# Out:
# 8
# 22
# 1
# 374
# 1

# %%
print("T", (arrhythmia_df["T"].isnull().sum()))
print("P", (arrhythmia_df["P"].isnull().sum()))
print("QRST", (arrhythmia_df["QRST"].isnull().sum()))
print("J", (arrhythmia_df["J"].isnull().sum()))
print("heartrate", (arrhythmia_df["heartrate"].isnull().sum()))
# Out:
# T 8
# P 22
# QRST 1
# J 374
# heartrate 1

# %% [markdown]
# ## 4) Dropping Columns with Majority NaNs...

# %% [markdown]
# ### The J Column (TOO MANY 'NaNs')

# %%
#83% are nulls--this column will be dropped
arrhythmia_df = arrhythmia_df.drop(['J'], axis = 1)

# %% [markdown]
# ### THIS IS ONE OF THE ERRORS I FOUND! (FIXED!)
#
# #### NOTE: .isnull.sum( ) is not recognizing "NaN" values
#
# EX: arrhythmia_df["heartrate"].isnull().sum()--> There is 1 NaN value in the dataset!

# %%
#This was ran BEFORE fixing the error('?' was not properly replaced by NaN)
arrhythmia_df["heartrate"].isnull().sum()
# Out:
# 0

# %%
arrhythmia_df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    1     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    1     155      55           93         106          386
# 451   78    1     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ... chV6_QwaveAmp chV6_RwaveAmp chV6_SwaveAmp  \
# 0          174        121  -16  ...           0.0           9.0          -0.9
# 1          149         39   25  ...           0.0           8.5           0.0
# 2          185        102   96  ...           0.0           9.5          -2.4
# 3          179        143   28  ...           0.0          12.2          -2.2
# 4          177        103  -16  ...           0.0          13.1          -3.6
# ..         ...        ...  ...  ...           ...           ...           ...
# 447        154        117  -37  ...           0.0           4.3          -5.0
# 448        201         73   86  ...           0.0          15.6          -1.6
# 449        194        116  -85  ...           0.0          16.3         -28.6
# 450        218         63   54  ...          -0.4          12.0          -0.7
# 451        138         78   28  ...           0.0          10.4          -1.8
#
#     chV6_RPwaveAmp  chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# 0              0.0             0.0            0.9            2.9       23.3
# 1              0.0             0.0            0.2            2.1       20.4
# 2              0.0             0.0            0.3            3.4       12.3
# 3              0.0             0.0            0.4            2.6       34.6
# 4              0.0             0.0           -0.1            3.9       25.4
# ..             ...             ...            ...            ...        ...
# 447            0.0             0.0            0.7            0.6       -4.4
# 448            0.0             0.0            0.4            2.4       38.0
# 449            0.0             0.0            1.5            1.0      -44.2
# 450            0.0             0.0            0.5            2.4       25.0
# 451            0.0             0.0            0.5            1.6       21.3
#
#      chV6_QRSTA  class
# 0          49.4      8
# 1          38.8      6
# 2          49.0     10
# 3          61.6      1
# 4          62.8      7
# ..          ...    ...
# 447        -0.5      1
# 448        62.4     10
# 449       -33.2      2
# 450        46.6      1
# 451        32.8      1
#
# [450 rows x 279 columns]

# %% [markdown]
# ### CURRENT COUNT: (279, 450)

# %%
type(arrhythmia_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 4) Interpolating... (Didn't Work)
#
#
# ### (use simple imputer from sklearn)

# %%
#arrhythmia_df = arrhythmia_df.interpolate(method='polynomial', order=1, axis=0, limit_area='inside')

# %% [markdown]
# ### Confirming Interpolation... (Didn't Work)

# %%
for i in arrhythmia_df.isnull().sum():
    if i > 0:
        print(i)
# Out:
# 8
# 22
# 1
# 1

# %%
print("T", (arrhythmia_df["T"].isnull().sum()))
print("P", (arrhythmia_df["P"].isnull().sum()))
print("QRST", (arrhythmia_df["QRST"].isnull().sum()))
print("heartrate", (arrhythmia_df["heartrate"].isnull().sum()))
# Out:
# T 8
# P 22
# QRST 1
# heartrate 1

# %% [markdown]
# ## 5) Trying to replace 'NaNs' with Mode or Mean of Column...

# %%
#arrhythmia_df[entered_all_column_names_above].value_counts()

# %% [markdown]
# ### NOTE: Look into how to code the mean for dataset containing negative & positive number.
#
# #### (In the meantime, I used mode to replace NaNs)

# %%
#All Columns to a list 
All_Columns = arrhythmia_df.columns.tolist()

# %%
NaNs_list = []
for i in All_Columns:
    null_amount = arrhythmia_df[i].isnull().sum()
    if null_amount > 0:
        NaNs_list.append(i)

# %%
NaNs_list
# Out:
# ['T', 'P', 'QRST', 'heartrate']

# %%
for i in NaNs_list:
    arrhythmia_df[i].fillna(arrhythmia_df[i].mode()[0], inplace=True)

# %% [markdown]
# ### Confirming NaNs are Filled...

# %%
print("T", (arrhythmia_df["T"].isnull().sum()))
print("P", (arrhythmia_df["P"].isnull().sum()))
print("QRST", (arrhythmia_df["QRST"].isnull().sum()))
print("heartrate", (arrhythmia_df["heartrate"].isnull().sum()))
# Out:
# T 0
# P 0
# QRST 0
# heartrate 0

# %%
type(arrhythmia_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 6) Transform Categorical Data
#
# #### Do all columns need to have the same datatype?

# %%
for col in arrhythmia_df:
    if (arrhythmia_df[col].dtypes) == object:
        print(col, arrhythmia_df[col].dtypes)
# Out:
# T object
# P object
# QRST object
# heartrate object

# %%
for col in arrhythmia_df:
    if (arrhythmia_df[col].dtypes) == object:
        arrhythmia_df[col] = arrhythmia_df[col].astype("int")

# %%
for col in arrhythmia_df:
    print(arrhythmia_df[col].dtypes)
# Out:
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# int64

# %% [markdown]
# ### TRY SKIPPING THIS STEPS 7-8 IF MODEL GIVES ERROR...something is fishy here...where did the NaNs come from?
#
# ## 7) Checking the Variance...
#
# As you can see below there is alot of variance between the columns!

# %%
#for col in arrhythmia_df:
    #print(col, arrhythmia_df[col].var())
# Out:
# age 262.9011828755259
# sex 0.24793862905221478
# height 108.41380351398169
# weight 260.26449393714427
# QRSduration 237.00333580796834
# PRinterval 2017.676594902252
# Q-Tinterval 1040.727389260084
# Tinterval 1270.5470378619154
# Pinterval 667.4107597129423
# QRS 2047.9572828507792
# T 3306.6154120267256
# P 805.6373224449393
# QRST 1290.6829200692898
# heartrate 166.53563474387528
# chDI_Qwave 113.78601336302894
# chDI_Rwave 331.0559564464242
# chDI_Swave 422.0915614946795
# chDI_RPwave 2.474159861420441
# chDI_SPwave 0.0
# chDI_intrinsicReflecttions 100.2113140311804
# chDI_RRwaveExists 0.0022222222222222227
# chDI_DD_RRwaveExists 0.011012125711457564
# chDI_RPwaveExists 0.011012125711457564
# chDI_DD_RPwaveExists 0.0044345459044790895
# chDI_RTwaveExists 0.0044345459044790895
# chDI_DD_RTwaveExists 0.008829497649096758
# chDII_Qwave 126.32318732986883
# chDII_Rwave 297.2504627567434
# chDII_Swave 445.25699579312055
# chDII_RPwave 8.75537738183618
# chDII_SPwave 6.96888888888889
# chDII_intrinsicReflecttions 92.44642415243752
# chDII_RRwaveExists 0.017500618658747833
# chDII_DD_RRwaveExists 0.028116802771591193
# chDII_RPwaveExists 0.0022222222222222227
# chDII_DD_RPwaveExists 0.0044345459044790895
# chDII_RTwaveExists 0.0044345459044790895
# chDII_DD_RTwaveExists 0.0153476862162831
# chDIII_Qwave 480.88128681019555
# chDIII_Rwave 534.4669933184855
# chDIII_Swave 645.3480623608018
# chDIII_RPwave 84.19175451620885
# chDIII_SPwave 9.803830734966592
# chDIII_intrinsicReflecttions 337.4617371937639
# chDIII_RRwaveExists 0.0022222222222222227
# chDIII_DD_RRwaveExists 0.03436773075971294
# chDIII_RPwaveExists 0.002222222222222223
# chDIII_DD_RPwaveExists 0.01750061865874783
# chDIII_RTwaveExists 0.01101212571145756
# chDIII_DD_RTwaveExists 0.002222222222222223
# chAVR_Qwave 617.9964167285326
# chAVR_Rwave 302.40783964365255
# chAVR_Swave 338.5371145756
# chAVR_RPwave 106.93503588220739
# chAVR_SPwave 2.275555555555556
# chAVR_intrinsicReflecttions 783.6210047018064
# chAVR_RRwaveExists 0.011012125711457564
# chAVR_DD_RRwaveExists 0.0044345459044790895
# chAVR_RPwaveExists 0.0044345459044790895
# chAVR_DD_RPwaveExists 0.0044345459044790895
# chAVR_RTwaveExists 0.0022222222222222227
# chAVR_DD_RTwaveExists 0.008829497649096758
# chAVL_Qwave 291.13585746102456
# chAVL_Rwave 508.9662162830983
# chAVL_Swave 530.4432764167285
# chAVL_RPwave 27.695006186587474
# chAVL_SPwave 0.0
# chAVL_intrinsicReflecttions 239.50673595644645
# chAVL_RRwaveExists 0.0
# chAVL_DD_RRwaveExists 0.01750061865874783
# chAVL_RPwaveExists 0.0022222222222222235
# chAVL_DD_RPwaveExists 0.0022222222222222222
# chAVL_RTwaveExists 0.006636971046770601
# chAVL_DD_RTwaveExists 0.0
# chAVF_Qwave 236.69586735956446
# chAVF_Rwave 406.5350952734472
# chAVF_Swave 539.3802326156892
# chAVF_RPwave 20.754387527839643
# chAVF_SPwave 6.563840633506556
# chAVF_intrinsicReflecttions 169.32846325167037
# chAVF_RRwaveExists 0.0044345459044790895
# chAVF_DD_RRwaveExists 0.023900024746349915
# chAVF_RPwaveExists 0.0
# chAVF_DD_RPwaveExists 0.002222222222222223
# chAVF_RTwaveExists 0.0022222222222222227
# chAVF_DD_RTwaveExists 0.002222222222222223
# chV1_Qwave 721.3758970551843
# chV1_Rwave 265.39775303142784
# chV1_Swave 567.3988814649839
# chV1_RPwave 158.89524375154664
# chV1_SPwave 2.3741450136104922
# chV1_intrinsicReflecttions 365.27481316505816
# chV1_RRwaveExists 0.0044345459044790895
# chV1_DD_RRwaveExists 0.0153476862162831
# chV1_RPwaveExists 0.008829497649096758
# chV1_DD_RPwaveExists 0.0066369710467706
# chV1_RTwaveExists 0.011012125711457562
# chV1_DD_RTwaveExists 0.02177678792378124
# chV2_Qwave 441.7916357337292
# chV2_Rwave 264.4434545904479
# chV2_Swave 308.0131848552338
# chV2_RPwave 70.64390002474634
# chV2_SPwave 5.099727790150953
# chV2_intrinsicReflecttions 171.5748775055679
# chV2_RRwaveExists 0.008829497649096756
# chV2_DD_RRwaveExists 0.008829497649096758
# chV2_RPwaveExists 0.013184855233853012
# chV2_DD_RPwaveExists 0.0066369710467706
# chV2_RTwaveExists 0.008829497649096758
# chV2_DD_RTwaveExists 0.017500618658747826
# chV3_Qwave 267.6239742637961
# chV3_Rwave 185.00767136847313
# chV3_Swave 270.09781737193765
# chV3_RPwave 27.749883692155397
# chV3_SPwave 4.151447661469933
# chV3_intrinsicReflecttions 103.14468695867359
# chV3_RRwaveExists 0.023900024746349918
# chV3_DD_RRwaveExists 0.00443454590447909
# chV3_RPwaveExists 0.0066369710467706
# chV3_DD_RPwaveExists 0.008829497649096756
# chV3_RTwaveExists 0.0066369710467706
# chV3_DD_RTwaveExists 0.011012125711457564
# chV4_Qwave 133.3516258351893
# chV4_Rwave 107.97770848799803
# chV4_Swave 285.2541450136105
# chV4_RPwave 8.88247463499134
# chV4_SPwave 4.11810937886662
# chV4_intrinsicReflecttions 60.615807968324674
# chV4_RRwaveExists 0.0044345459044790895
# chV4_DD_RRwaveExists 0.013184855233853014
# chV4_RPwaveExists 0.0
# chV4_DD_RPwaveExists 0.0
# chV4_RTwaveExists 0.0044345459044790895
# chV4_DD_RTwaveExists 0.01750061865874783
# chV5_Qwave 115.95418955704035
# chV5_Rwave 143.39769364018807
# chV5_Swave 299.63917842118286
# chV5_RPwave 10.538064835436773
# chV5_SPwave 0.0
# chV5_intrinsicReflecttions 109.93247216035637
# chV5_RRwaveExists 0.0
# chAVF_intrinsicReflecttions 0.0264575723830735
# chAVF_RRwaveExists 0.00443454590447909
# chAVF_DD_RRwaveExists 0.02390002474634992
# chAVF_RPwaveExists nan
# chAVF_DD_RPwaveExists 0.002222222222222223
# chAVF_RTwaveExists 0.0022222222222222227
# chAVF_DD_RTwaveExists 0.002222222222222223
# chV1_Qwave 0.0368153432318733
# chV1_Rwave 0.00576789705518436
# chV1_Swave 0.04221171046770602
# chV1_RPwave 0.024827381836179163
# chV1_SPwave 0.0030336570155902014
# chV1_intrinsicReflecttions 0.027278169265033406
# chV1_RRwaveExists 0.00443454590447909
# chV1_DD_RRwaveExists 0.0153476862162831
# chV1_RPwaveExists 0.008829497649096758
# chV1_DD_RPwaveExists 0.0066369710467706
# chV1_RTwaveExists 0.011012125711457562
# chV1_DD_RTwaveExists 0.02177678792378124
# chV2_Qwave 0.02543043603068548
# chV2_Rwave 0.005697109131403116
# chV2_Swave 0.02638405147240782
# chV2_RPwave 0.013641825785696612
# chV2_SPwave 0.0049802029200692885
# chV2_intrinsicReflecttions 0.01858079732739421
# chV2_RRwaveExists 0.008829497649096756
# chV2_DD_RRwaveExists 0.008829497649096756
# chV2_RPwaveExists 0.013184855233853012
# chV2_DD_RPwaveExists 0.0066369710467706
# chV2_RTwaveExists 0.008829497649096756
# chV2_DD_RTwaveExists 0.017500618658747826
# chV3_Qwave 0.029086857708487998
# chV3_Rwave 0.010518038109378864
# chV3_Swave 0.021496609750061863
# chV3_RPwave 0.0048089131403118044
# chV3_SPwave 0.0032131457560009894
# chV3_intrinsicReflecttions 0.013221888146498391
# chV3_RRwaveExists 0.023900024746349918
# chV3_DD_RRwaveExists 0.00443454590447909
# chV3_RPwaveExists 0.0066369710467706
# chV3_DD_RPwaveExists 0.008829497649096756
# chV3_RTwaveExists 0.0066369710467706
# chV3_DD_RTwaveExists 0.011012125711457564
# chV4_Qwave 0.01720267260579065
# chV4_Rwave 0.012914147983172482
# chV4_Swave 0.018574571145756003
# chV4_RPwave 0.015419084879980203
# chV4_SPwave 0.002573818361791637
# chV4_intrinsicReflecttions 0.016757701559020042
# chV4_RRwaveExists 0.00443454590447909
# chV4_DD_RRwaveExists 0.013184855233853014
# chV4_RPwaveExists nan
# chV4_DD_RPwaveExists nan
# chV4_RTwaveExists 0.0044345459044790895
# chV4_DD_RTwaveExists 0.01750061865874783
# chV5_Qwave 0.014990645879732742
# chV5_Rwave 0.007806810690423162
# chV5_Swave 0.02083810937886662
# chV5_RPwave 0.002934127196238555
# chV5_SPwave nan
# chV5_intrinsicReflecttions 0.00629732293986637
# chV5_RRwaveExists nan
# chV5_DD_RRwaveExists 0.0066369710467706
# chV5_RPwaveExists nan
# chV5_DD_RPwaveExists 0.002222222222222223
# chV5_RTwaveExists nan
# chV5_DD_RTwaveExists 0.006636971046770598
# chV6_Qwave 0.01584698094531057
# chV6_Rwave 0.01028493986636971
# chV6_Swave 0.042543214055926745
# chV6_RPwave 0.004443620885919328
# chV6_SPwave nan
# chV6_intrinsicReflecttions 0.009718767136847318
# chV6_RRwaveExists 0.0022222222222222227
# chV1_PwaveAmp 0.01151236030685474
# chV1_TwaveAmp 0.006822701806483544
# chV1_QRSA 0.002368287552585993
# chV1_QRSTA 0.0035246231130908203
# chV2_JJwaveAmp 0.0069520856223706995
# chV2_QwaveAmp 0.015521742637960901
# chV2_RwaveAmp 0.01383376837416481
# chV2_SwaveAmp 0.018515773818361794
# chV2_RPwaveAmp 0.004265429349170998
# chV2_SPwaveAmp 0.002987973273942094
# chV2_PwaveAmp 0.007613363028953228
# chV2_TwaveAmp 0.01212955407077456
# chV2_QRSA 0.006092464241524376
# chV2_QRSTA 0.014973865874783469
# chV3_JJwaveAmp 0.006207570403365502
# chV3_QwaveAmp 0.010850556297946052
# chV3_RwaveAmp 0.03417041375897055
# chV3_SwaveAmp 0.021442244988864143
# chV3_RPwaveAmp 0.0031229799554565695
# chV3_SPwaveAmp 0.002239331353625339
# chV3_PwaveAmp 0.009402140559267507
# chV3_TwaveAmp 0.009554936401880721
# chV3_QRSA 0.006232281613462014
# chV3_QRSTA 0.017359784211828756
# chV4_JJwaveAmp 0.006197853996535511
# chV4_QwaveAmp 0.00746797772828508
# chV4_RwaveAmp 0.026321554070774557
# chV4_SwaveAmp 0.013956421182875526
# chV4_RPwaveAmp 0.0048615317990596384
# chV4_SPwaveAmp 0.0026480890868596893
# chV4_PwaveAmp 0.0062458975501113595
# chV4_TwaveAmp 0.010503978718139073
# chV4_QRSA 0.012055463499133879
# chV4_QRSTA 0.010064958673595643
# chV5_JJwaveAmp 0.006526049987626826
# chV5_QwaveAmp 0.004888847315021033
# chV5_RwaveAmp 0.026466449393714425
# chV5_SwaveAmp 0.008508971046770602
# chV5_RPwaveAmp 0.0022764543429844098
# chV5_SPwaveAmp nan
# chV5_PwaveAmp 0.01000607968324672
# chV5_TwaveAmp 0.016474467211086367
# chV5_QRSA 0.01395443157634249
# chV5_QRSTA 0.016209020044543433
# chV6_JJwaveAmp 0.0051355233853006685
# chV6_QwaveAmp 0.01797233358079683
# chV6_RwaveAmp 0.021593540707745603
# chV6_SwaveAmp 0.004851543677307597
# chV6_RPwaveAmp 0.003914587478346945
# chV6_SPwaveAmp nan
# chV6_PwaveAmp 0.011657191784211828
# chV6_TwaveAmp 0.01421510566691413
# chV6_QRSA 0.010154520663202177
# chV6_QRSTA 0.014310749319475378
# class 0.08652319178421183

# %% [markdown]
# ## 8) Remove Columns with Majority Nulls--> Resulting from Normalization
#
# ## (step 7 not ran, no need for step 8)
# ## (no NaNs in the dataset)

# %%
list_col = []
for col in arrhythmia_df:
    if (arrhythmia_df[col].isnull().sum()) > 0:
        list_col.append(col)
        print(col, (arrhythmia_df[col].isnull().sum()))

# %%
list_col
# Out:
# []

# %%
#arrhythmia_df = arrhythmia_df.drop(['chDI_SPwave','chAVL_SPwave','chAVL_RRwaveExists',
                                              #'chAVL_DD_RTwaveExists','chAVF_RPwaveExists',
                                              #'chV4_RPwaveExists','chV4_DD_RPwaveExists','chV5_SPwave',
                                              #'chV5_RRwaveExists', 'chV5_RPwaveExists','chV5_RTwaveExists',
                                              #'chV6_SPwave','chV6_DD_RPwaveExists','chV6_RTwaveExists',
                                              #'chDI_SPwaveAmp','chAVL_SPwaveAmp','chV5_SPwaveAmp',
                                              #'chV6_SPwaveAmp'], axis = 1)

# %% [markdown]
# ### COUNT:  261, 450 (IF STEPS 7-8 WERE USED)

# %% [markdown]
# ### CURRENT VALUE : 279, 450

# %%
arrhythmia_df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    1     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    1     155      55           93         106          386
# 451   78    1     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ...  chV6_QwaveAmp  chV6_RwaveAmp  \
# 0          174        121  -16  ...            0.0            9.0
# 1          149         39   25  ...            0.0            8.5
# 2          185        102   96  ...            0.0            9.5
# 3          179        143   28  ...            0.0           12.2
# 4          177        103  -16  ...            0.0           13.1
# ..         ...        ...  ...  ...            ...            ...
# 447        154        117  -37  ...            0.0            4.3
# 448        201         73   86  ...            0.0           15.6
# 449        194        116  -85  ...            0.0           16.3
# 450        218         63   54  ...           -0.4           12.0
# 451        138         78   28  ...            0.0           10.4
#
#      chV6_SwaveAmp  chV6_RPwaveAmp  chV6_SPwaveAmp  chV6_PwaveAmp  \
# 0             -0.9             0.0             0.0            0.9
# 1              0.0             0.0             0.0            0.2
# 2             -2.4             0.0             0.0            0.3
# 3             -2.2             0.0             0.0            0.4
# 4             -3.6             0.0             0.0           -0.1
# ..             ...             ...             ...            ...
# 447           -5.0             0.0             0.0            0.7
# 448           -1.6             0.0             0.0            0.4
# 449          -28.6             0.0             0.0            1.5
# 450           -0.7             0.0             0.0            0.5
# 451           -1.8             0.0             0.0            0.5
#
#      chV6_TwaveAmp  chV6_QRSA  chV6_QRSTA  class
# 0              2.9       23.3        49.4      8
# 1              2.1       20.4        38.8      6
# 2              3.4       12.3        49.0     10
# 3              2.6       34.6        61.6      1
# 4              3.9       25.4        62.8      7
# ..             ...        ...         ...    ...
# 447            0.6       -4.4        -0.5      1
# 448            2.4       38.0        62.4     10
# 449            1.0      -44.2       -33.2      2
# 450            2.4       25.0        46.6      1
# 451            1.6       21.3        32.8      1
#
# [450 rows x 279 columns]

# %% [markdown]
# #### REMINDER: 1.00 = Regular Heartbeat

# %%
arrhythmia_df['class'].value_counts()
# Out:
# 1.00    245
# 0.40     50
# 0.93     44
# 0.67     25
# 0.00     22
# 0.87     15
# 0.80     15
# 0.73     11
# 0.47      9
# 0.07      5
# 0.13      4
# 0.60      3
# 0.53      2
# Name: class, dtype: int64

# %%
type(arrhythmia_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 9) Dropping Columns through Correlation Matrix

# %%
cor_matrix = arrhythmia_df.corr().abs() #abs: takes absolute value of correlation values

# %%
from sklearn import datasets

upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
upper_tri
# Out:
#                age       sex    height    weight  QRSduration  PRinterval  \
# age            NaN  0.061665  0.243302  0.352977     0.008168    0.039119
# sex            NaN       NaN  0.460879  0.257447     0.338382    0.048942
# height         NaN       NaN       NaN  0.574054     0.047447    0.081453
# weight         NaN       NaN       NaN       NaN     0.097892    0.120221
# QRSduration    NaN       NaN       NaN       NaN          NaN    0.021415
# ...            ...       ...       ...       ...          ...         ...
# chV6_PwaveAmp  NaN       NaN       NaN       NaN          NaN         NaN
# chV6_TwaveAmp  NaN       NaN       NaN       NaN          NaN         NaN
# chV6_QRSA      NaN       NaN       NaN       NaN          NaN         NaN
# chV6_QRSTA     NaN       NaN       NaN       NaN          NaN         NaN
# class          NaN       NaN       NaN       NaN          NaN         NaN
#
#                Q-Tinterval  Tinterval  Pinterval       QRS  ...  \
# age               0.154391   0.015105   0.098167  0.251801  ...
# sex               0.072672   0.187283   0.085497  0.072584  ...
# height            0.049501   0.047882   0.132786  0.128398  ...
# weight            0.058241   0.140564   0.120577  0.153145  ...
# QRSduration       0.220961   0.396953   0.049144  0.144556  ...
# ...                    ...        ...        ...       ...  ...
# chV6_PwaveAmp          NaN        NaN        NaN       NaN  ...
# chV6_TwaveAmp          NaN        NaN        NaN       NaN  ...
# chV6_QRSA              NaN        NaN        NaN       NaN  ...
# chV6_QRSTA             NaN        NaN        NaN       NaN  ...
# class                  NaN        NaN        NaN       NaN  ...
#
#                chV6_QwaveAmp  chV6_RwaveAmp  chV6_SwaveAmp  chV6_RPwaveAmp  \
# age                 0.166185       0.177108       0.061554        0.091021
# sex                 0.228771       0.043770       0.091940        0.027427
# height              0.061722       0.014724       0.071417        0.008875
# weight              0.050264       0.048485       0.023966        0.047582
# QRSduration         0.199545       0.089928       0.233070        0.013813
# ...                      ...            ...            ...             ...
# chV6_PwaveAmp            NaN            NaN            NaN             NaN
# chV6_TwaveAmp            NaN            NaN            NaN             NaN
# chV6_QRSA                NaN            NaN            NaN             NaN
# chV6_QRSTA               NaN            NaN            NaN             NaN
# class                    NaN            NaN            NaN             NaN
#
#                chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# age                       NaN       0.024823       0.273189   0.004119
# sex                       NaN       0.009666       0.068842   0.028777
# height                    NaN       0.051245       0.067138   0.057516
# weight                    NaN       0.028774       0.145250   0.035322
# QRSduration               NaN       0.064731       0.221894   0.128127
# ...                       ...            ...            ...        ...
# chV6_PwaveAmp             NaN            NaN       0.041673   0.064723
# chV6_TwaveAmp             NaN            NaN            NaN   0.121468
# chV6_QRSA                 NaN            NaN            NaN        NaN
# chV6_QRSTA                NaN            NaN            NaN        NaN
# class                     NaN            NaN            NaN        NaN
#
#                chV6_QRSTA     class
# age              0.221985  0.090826
# sex              0.045815  0.178393
# height           0.017255  0.033703
# weight           0.075807  0.088700
# QRSduration      0.085211  0.324365
# ...                   ...       ...
# chV6_PwaveAmp    0.058376  0.088195
# chV6_TwaveAmp    0.693580  0.031134
# chV6_QRSA        0.607237  0.005520
# chV6_QRSTA            NaN  0.007727
# class                 NaN       NaN
#
# [279 rows x 279 columns]

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.75)]
print(to_drop)
# Out:
# ['chAVR_Swave', 'chAVR_intrinsicReflecttions', 'chAVR_DD_RTwaveExists', 'chAVF_Swave', 'chV1_Swave', 'chV2_Rwave', 'chV3_intrinsicReflecttions', 'chV6_Qwave', 'chV6_Rwave', 'chV6_intrinsicReflecttions', 'chDI_QwaveAmp', 'chDI_RPwaveAmp', 'chDI_QRSA', 'chDII_QwaveAmp', 'chDII_SwaveAmp', 'chDII_RPwaveAmp', 'chDII_SPwaveAmp', 'chDII_QRSA', 'chDIII_QwaveAmp', 'chDIII_Rw
                                         'chAVL_QRSTA', 'chAVF_QwaveAmp', 'chAVF_RwaveAmp', 'chAVF_SwaveAmp', 
                                         'chAVF_RPwaveAmp', 'chAVF_SPwaveAmp', 'chAVF_PwaveAmp', 'chAVF_TwaveAmp', 
                                         'chAVF_QRSA', 'chAVF_QRSTA', 'chV1_QwaveAmp', 'chV1_RPwaveAmp', 
                                         'chV1_SPwaveAmp', 'chV2_QwaveAmp', 'chV2_RPwaveAmp', 'chV2_SPwaveAmp', 
                                         'chV3_JJwaveAmp', 'chV3_QwaveAmp', 'chV3_RwaveAmp', 'chV3_RPwaveAmp', 
                                         'chV3_SPwaveAmp', 'chV3_TwaveAmp', 'chV3_QRSA', 'chV3_QRSTA', 'chV4_JJwaveAmp', 
                                         'chV4_QwaveAmp', 'chV4_SwaveAmp', 'chV4_RPwaveAmp', 'chV4_SPwaveAmp', 
                                         'chV4_TwaveAmp', 'chV5_QwaveAmp', 'chV5_RPwaveAmp', 'chV5_PwaveAmp', 
                                         'chV5_TwaveAmp', 'chV5_QRSTA', 'chV6_JJwaveAmp', 'chV6_QwaveAmp',
                                         'chV6_RwaveAmp', 'chV6_SwaveAmp', 'chV6_RPwaveAmp', 'chV6_PwaveAmp',
                                         'chV6_TwaveAmp', 'chV6_QRSA', 'chV6_QRSTA'], axis = 1)

# %% [markdown]
# ###  COUNT: 177, 450 (IF STEPS 7-8 WERE USED)

# %% [markdown]
# ### CURRENT COUNT: 195, 450

# %%
arrhythmia_NEW_df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    1     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    1     155      55           93         106          386
# 451   78    1     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ...  chV4_PwaveAmp  chV4_QRSA  chV4_QRSTA  \
# 0          174        121  -16  ...            0.9       17.7        70.7
# 1          149         39   25  ...            0.5       11.8        34.6
# 2          185        102   96  ...            0.5       -3.0        20.7
# 3          179        143   28  ...            0.1       28.8        63.1
# 4          177        103  -16  ...           -0.1       16.2        63.2
# ..         ...        ...  ...  ...            ...        ...         ...
# 447        154        117  -37  ...            0.8      -20.1        -9.5
# 448        201         73   86  ...            0.7       69.2       129.3
# 449        194        116  -85  ...            1.0      -71.2      -161.4
# 450        218         63   54  ...            0.6       17.5        56.2
# 451        138         78   28  ...            0.5       44.0        60.8
#
#      chV5_JJwaveAmp  chV5_RwaveAmp  chV5_SwaveAmp  chV5_SPwaveAmp  chV5_QRSA  \
# 0              -0.4           13.5           -4.0             0.0       25.5
# 1              -0.4           11.0           -2.4             0.0       21.6
# 2               1.3           11.1           -3.4             0.0       11.5
# 3               0.1           15.2           -3.7             0.0       36.8
# 4              -0.2            9.1           -0.9             0.0       21.7
# ..              ...            ...            ...             ...        ...
# 447             0.1            4.1           -8.3             0.0       -8.4
# 448            -0.7           21.2           -2.8             0.0       50.7
# 449             0.2           22.0          -30.8             0.0      -39.6
# 450             0.1           15.3           -3.5             0.0       29.7
# 451            -0.4           12.5           -2.9             0.0       26.7
#
#      chV6_SPwaveAmp  class
# 0               0.0      8
# 1               0.0      6
# 2               0.0     10
# 3               0.0      1
# 4               0.0      7
# ..              ...    ...
# 447             0.0      1
# 448             0.0     10
# 449             0.0      2
# 450             0.0      1
# 451             0.0      1
#
# [450 rows x 195 columns]

# %% [markdown]
# ## 10) Making Target Binary
#
# ### Predictions need to sum to 1 so that they can be interpreted as probability by the NN model!

# %%
arrhythmia_NEW_df['class'].value_counts()
# Out:
# 1     245
# 10     50
# 2      44
# 6      25
# 16     22
# 3      15
# 4      15
# 5      11
# 9       9
# 15      5
# 14      4
# 7       3
# 8       2
# Name: class, dtype: int64

# %% [markdown]
# ### STEP 1: Replace Regular Heartbeat with '11' as a temporary placeholder

# %%
for n in arrhythmia_NEW_df['class']:
    if n == 1:
        arrhythmia_NEW_df = arrhythmia_NEW_df.replace([n], 11)

# %%
arrhythmia_NEW_df['class'].value_counts()
# Out:
# 11    245
# 10     50
# 2      44
# 6      25
# 16     22
# 3      15
# 4      15
# 5      11
# 9       9
# 15      5
# 14      4
# 7       3
# 8       2
# Name: class, dtype: int64

# %% [markdown]
# ### STEP 2: Replace Irregular Heartbeat with '1' as a permanent "probability" value

# %%
for n in arrhythmia_NEW_df['class']:
    if n != 11:
        arrhythmia_NEW_df = arrhythmia_NEW_df.replace([n], 1)

# %%
arrhythmia_NEW_df['class'].value_counts()
# Out:
# 11    245
# 1     205
# Name: class, dtype: int64

# %% [markdown]
# ### STEP 3: Replace Regular Heartbeat with '0' as a permanent "probability" value

# %%
for n in arrhythmia_NEW_df['class']:
    if n == 11:
        arrhythmia_NEW_df = arrhythmia_NEW_df.replace([n], 0)

# %%
arrhythmia_NEW_df['class'].value_counts()
# Out:
# 0    245
# 1    205
# Name: class, dtype: int64

# %% [markdown]
# ## 11) Converting Target('Class') to "Int64"
#
# ### (NOT NEEDED BECAUSE STEPS 7-8 NOT RAN)

# %%
arrhythmia_NEW_df['class'].dtype
# Out:
# dtype('int64')

# %%
#arrhythmia_NEW_df['class'] = arrhythmia_NEW_df['class'].astype("int64")

# %%
#arrhythmia_NEW_df['class'].dtype
# Out:
# dtype('int64')

# %%
#arrhythmia_NEW_df['class'].value_counts()
# Out:
# 0    245
# 1    205
# Name: class, dtype: int64

# %%
type(arrhythmia_NEW_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 12) Splitting Data into Train and Test Sets...

# %%
X = arrhythmia_NEW_df.drop('class', axis=1).values
y = arrhythmia_NEW_df['class'].values 

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42, stratify=y)

#Standardize
sc= StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X_train.shape
# Out:
# (315, 194)

# %%
X_test.shape
# Out:
# (135, 194)

# %%
y_test.shape
# Out:
# (135,)

# %%
y_train.shape
# Out:
# (315,)

# %%
arrhythmia_NEW_df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    0     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    0     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    0     155      55           93         106          386
# 451   78    0     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ...  chV4_PwaveAmp  chV4_QRSA  chV4_QRSTA  \
# 0          174        121  -16  ...            0.9       17.7        70.7
# 1          149         39   25  ...            0.5       11.8        34.6
# 2          185        102   96  ...            0.5       -3.0        20.7
# 3          179        143   28  ...            0.1       28.8        63.1
# 4          177        103  -16  ...           -0.1       16.2        63.2
# ..         ...        ...  ...  ...            ...        ...         ...
# 447        154        117  -37  ...            0.8      -20.1        -9.5
# 448        201         73   86  ...            0.7       69.2       129.3
# 449        194        116  -85  ...            0.0      -71.2      -161.4
# 450        218         63   54  ...            0.6       17.5        56.2
# 451        138         78   28  ...            0.5       44.0        60.8
#
#      chV5_JJwaveAmp  chV5_RwaveAmp  chV5_SwaveAmp  chV5_SPwaveAmp  chV5_QRSA  \
# 0              -0.4           13.5           -4.0             0.0       25.5
# 1              -0.4            0.0           -2.4             0.0       21.6
# 2               1.3           11.1           -3.4             0.0       11.5
# 3               0.1           15.2           -3.7             0.0       36.8
# 4              -0.2            9.1           -0.9             0.0       21.7
# ..              ...            ...            ...             ...        ...
# 447             0.1            4.1           -8.3             0.0       -8.4
# 448            -0.7           21.2           -2.8             0.0       50.7
# 449             0.2           22.0          -30.8             0.0      -39.6
# 450             0.1           15.3           -3.5             0.0       29.7
# 451            -0.4           12.5           -2.9             0.0       26.7
#
#      chV6_SPwaveAmp  class
# 0               0.0      1
# 1               0.0      1
# 2               0.0      1
# 3               0.0      0
# 4               0.0      1
# ..              ...    ...
# 447             0.0      0
# 448             0.0      1
# 449             0.0      1
# 450             0.0      0
# 451             0.0      0
#
# [450 rows x 195 columns]

# %% [markdown]
# ### Tensorflow estimator ValueError: logits and labels must have the same shape ((?, 1) vs (?,))
#
# ### You should reshape your labels as 2d-tensor (the first dimension will be the batch dimension and the second the scalar label):

# %%
#y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
#y_test = np.asarray(y_test).astype('float32').reshape((-1,1))

# %% [markdown]
# # NEURAL NETWORK (USING KERAS)

# %% [markdown]
# The Keras workflow has 4 steps.
#
# 1) First, you specify the architecture,
#
#         - How many layers do you want?
#         - How many nodes in each layer?
#         - What activation function do you want to use in each layer?
#
# 2) Compile the model.
#
#         - This specifies the loss function,
#         - Some details about how optimization works.
#
# 3) Then you fit the model.
#
#         - Which is that cycle of back-propagation and optimization of model weights with your data.
#
# 4) And finally you will want to use your model to make predictions.
#
#
# After you've specified a model, the next task is to compile it, which sets up the network for optimization, for instance creating an internal function to do back-propagation efficiently. The compile methods
#
# 2. Why you need to compile your model
# has two important arguments for you to choose. The first is what optimizer to use, which controls the learning rate.
#
# The second thing you specify is the loss function.

# %% [markdown]
# ## Specify/Create the Neural Network/Model

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
#allows you to seperate the binary outcomes 
from keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

# %% [markdown]
# ## USE to_categorical (above)

# %%
n_cols = X_train.shape[1] #194 columns excluding target/class
n_cols
# Out:
# 194

# %%
# Set up the model: model
model = Sequential()

# Add the first layer
model.add(Dense(100, activation='relu', input_shape = (n_cols,)))

# Add the second layer
#model.add(Dense(100, activation='relu'))

# Add the third layer
model.add(Dense(100, activation='relu'))

# Add the output layer
model.add(Dense(2, activation='sigmoid')) #2 nodes for the 2 possible outcomes --irregular vs regular

#softmax

# %% [markdown]
# ## Compile the Model

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %% [markdown]
# ## Fit the Model

# %%
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 9ms/step - loss: 0.7305 - accuracy: 0.5429
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6011 - accuracy: 0.6571
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5234 - accuracy: 0.7841
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.8254
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4142 - accuracy: 0.8381
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3685 - accuracy: 0.8476
# Epoch 7/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3282 - accuracy: 0.8889
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2928 - accuracy: 0.9016
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2591 - accuracy: 0.9206
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2307 - accuracy: 0.9333
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1991 - accuracy: 0.9460
# Epoch 12/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1743 - accuracy: 0.9619
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9714
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9746
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9778
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0891 - accuracy: 0.9810
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.9873
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0593 - accuracy: 0.9937
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9937
# Epoch 20/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.9968
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 27/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 30/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 31/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 49/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.7890e-04 - accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9.4262e-04 - accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.0304e-04 - accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.6728e-04 - accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.3616e-04 - accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.0658e-04 - accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.7720e-04 - accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.4805e-04 - accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.2063e-04 - accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.9666e-04 - accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.7282e-04 - accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.5015e-04 - accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 12ms/step - loss: 6.2845e-04 - accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.0755e-04 - accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 5.8962e-04 - accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6902e-04 - accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 6ms/step - loss: 5.5152e-04 - accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 5.3464e-04 - accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 5.1963e-04 - accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 5.0315e-04 - accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 0s 6ms/step - loss: 4.8874e-04 - accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 6ms/step - loss: 4.7414e-04 - accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.6058e-04 - accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4780e-04 - accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.3460e-04 - accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2412e-04 - accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1135e-04 - accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.0103e-04 - accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 7ms/step - loss: 3.8963e-04 - accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 11ms/step - loss: 3.7915e-04 - accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 10ms/step - loss: 3.6945e-04 - accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.5986e-04 - accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 3.5114e-04 - accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4234e-04 - accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3378e-04 - accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.2545e-04 - accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.1752e-04 - accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 0s 17ms/step - loss: 3.1004e-04 - accuracy: 1.0000 0s - loss: 3.1805e-04 - accuracy: 1.
# Epoch 99/100
# 10/10 [==============================] - ETA: 0s - loss: 4.2782e-04 - accuracy: 1.00 - 0s 3ms/step - loss: 3.0300e-04 - accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9577e-04 - accuracy: 1.0000

# %% [markdown]
# ## Make Predictions

# %%
# ERROR: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# Calculate predictions: predictions
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[9.96794581e-01, 4.24540043e-03],
#        [9.75700459e-06, 9.99954939e-01],
#        [9.98951077e-01, 9.36597586e-04],
#        [9.99989092e-01, 1.32760561e-05],
#        [8.88536513e-01, 1.24453664e-01],
#        [9.98091102e-01, 1.94752216e-03],
#        [6.71067357e-01, 3.83071601e-01],
#        [3.13669443e-04, 9.99586225e-01],
#        [9.99986887e-01, 1.61183380e-05],
#        [1.47351220e-09, 1.00000000e+00],
#        [8.41066957e-01, 1.18926048e-01],
#        [1.16725445e-01, 8.93856049e-01],
#        [5.56567311e-03, 9.93367195e-01],
#        [5.06111979e-03, 9.94741261e-01],
#        [9.99930024e-01, 8.65243783e-05],
#        [9.67145920e-01, 5.41410446e-02],
#        [1.14029646e-03, 9.98560309e-01],
#        [8.17699103e-11, 1.00000000e+00],
#        [3.97538861e-05, 9.99845028e-01],
#        [9.98864591e-01, 1.22669339e-03],
#        [9.99960303e-01, 5.01835093e-05],
#        [1.17203026e-05, 9.99969840e-01],
#        [6.73095499e-08, 1.00000000e+00],
#        [1.10482192e-18, 1.00000000e+00],
#        [8.54298890e-01, 1.33589119e-01],
#        [1.00000000e+00, 1.42317283e-10],
#        [9.99907851e-01, 1.37507915e-04],
#        [3.38501632e-02, 9.38984156e-01],
#        [9.99989033e-01, 8.60626551e-06],
#        [1.92879230e-01, 8.63539100e-01],
#        [1.02853775e-03, 9.99106050e-01],
#        [8.94889593e-01, 9.08916891e-02],
#        [8.93437564e-02, 9.11872447e-01],
#        [7.34192133e-03, 9.87773061e-01],
#        [9.91453946e-01, 8.39138031e-03],
#        [9.99958277e-01, 7.99312038e-05],
#        [9.99988556e-01, 1.55350244e-05],
#        [8.91638875e-01, 9.89120901e-02],
#        [9.74625826e-01, 2.70936787e-02],
#        [9.55749273e-01, 3.14292014e-02],
#        [1.56422138e-01, 8.59112978e-01],
#        [9.99072790e-01, 9.17643309e-04],
#        [9.99636352e-01, 6.75559044e-04],
#        [9.64087248e-01, 2.91186869e-02],
#        [4.06828476e-05, 9.99924660e-01],
#        [1.67733431e-03, 9.98103321e-01],
#        [2.20719318e-22, 1.00000000e+00],
#        [4.06587014e-06, 9.99985635e-01],
#        [9.98907745e-01, 2.13518739e-03],
#        [1.13179214e-11, 1.00000000e+00],
#        [1.56180633e-07, 9.99999404e-01],
#        [1.71189331e-05, 9.99946713e-01],
#        [9.99978065e-01, 3.82152284e-05],
#        [9.98243195e-08, 9.99999821e-01],
#        [9.98181224e-01, 3.13821435e-03],
#        [9.89918888e-01, 1.03228986e-02],
#        [3.42017529e-07, 9.99999642e-01],
#        [7.82836914e-01, 2.07059681e-01],
#        [9.96008694e-01, 2.56645679e-03],
#        [9.62095976e-01, 5.80563247e-02],
#        [1.97220743e-02, 9.72706914e-01],
#        [7.32109249e-02, 9.21739280e-01],
#        [9.99701142e-01, 3.90708447e-04],
#        [4.28882837e-02, 9.53048825e-01],
#        [6.62638426e-01, 3.08120131e-01],
#        [9.72626507e-02, 8.78455639e-01],
#        [2.57444808e-05, 9.99968767e-01]], dtype=float32)

# %% [markdown]
# ## Calculate Accuracy and look at Classification Report

# %%
# Evaluate accuracy
#calculate accuracy
from sklearn.metrics import balanced_accuracy_score as accuracy

accuracy_of_model = accuracy(y_test, predictions)
print(accuracy_of_model)

#model.evalute(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jl/_v7nhy4x6ns_kxmg8nxmzggr0000gn/T/ipykernel_25459/4013192022.py in <module>
#       3 from sklearn.metrics import balanced_accuracy_score as accuracy
#       4
# ----> 5 accuracy_of_model = accuracy(y_test, predictions)
#       6 print(accuracy_of_model)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py in balanced_accuracy_score(y_true, y_pred, sample_weight, adjusted)
#    1947
#    1948     """
# -> 1949     C = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
#    1950     with np.errstate(divide="ignore", invalid="ignore"):
#    1951         per_class = np.diag(C) / C.sum(axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     300
#     301     """
# --> 302     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     303     if y_type not in ("binary", "multiclass"):
#     304         raise ValueError("%s is not supported" % y_type)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %%
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jl/_v7nhy4x6ns_kxmg8nxmzggr0000gn/T/ipykernel_25459/4086614537.py in <module>
# ----> 1 print(classification_report(y_test, predictions))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2074     """
#    2075
# -> 2076     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2077
#    2078     if labels is None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# #### 4.	Write another algorithm to predict the same result as the previous question using either KNN or logistic regression.

# %%
from sklearn.linear_model import LogisticRegression

# %%
#Logistic regression approach
regression = LogisticRegression(random_state=42).fit(X_train, y_train)

#regression.fit(X_train, y_train)

y_predicted = regression.predict(X_test)

# %%
regression.score(X_test, y_test)

accuracy = regression.score(X_test, y_test)
print("accuracy = ", accuracy * 100, "%")
# Out:
# accuracy =  74.07407407407408 %

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77        74
#            1       0.72      0.70      0.71        61
#
#     accuracy                           0.74       135
#    macro avg       0.74      0.74      0.74       135
# weighted avg       0.74      0.74      0.74       135

# %% [markdown]
# #### 5.	Create a neural network using pytorch to predict the same result as question 3.

# %%
import torch

# %%
# import torch neural network
import torch.nn as nn

# the following is imported because it has activation functions in it which is  convert the node input to 
#an ouput so that the algorithm can learn the complex patterns in the data.
import torch.nn.functional as F

#create tensors from our data = matrices (select tensor type that we need)

#redefine X_train and X_test based on the datatype we need to use(float)--pass in the matrices above(X_train, X_test)
X_train = torch.FloatTensor(X_train) 
X_test = torch.FloatTensor(X_test)

# %%
#redefine y_train and y_test based on the datatype we need to use(int-use long)--pass in the matrices above(y_train, y_test)
y_train = torch.LongTensor(y_train)

# %%
y_test = torch.LongTensor(y_test)

#y_test = torch.LongTensor(y_test.to_numpy())

# %%
#create an artificial neural network using class that accepts a NN module
class ANN_Model(nn.Module):
    
    #initiialize the class and its attributes that everything you create from that class will have
    # self: refers to the object itself
    # the other parameters (data we pass in) are part of the NN module we imported
        # input_features-->8 columns excluding target variable
        # hidden layers--> 20 nodes or perceptrons
        # 2 output features--> regular, irregular
    def __init__(self, input_features=194,hidden1=40,hidden2=40,out_features=2):
        
        super().__init__() #super is a computed indirect reference. So, it isolates changes
        # and makes sure that children in the layers of multiple inheritence are calling
        #the right parents, "parent and child need to be able to talk to each other" allows the layers and 
        #hence the nodes talk to each other. this is how we keep track of the trail
        
        #first connection is referring to all the connections between the input features 
        #and the first layer--hidden1.
        self.layer_1_connection = nn.Linear(input_features, hidden1)
        
        #second connection is referring to all the connections between hidden1 
        #and hidden2.
        self.layer_2_connection = nn.Linear(hidden1, hidden2)
        
        #third connection is referring to all the connections between hidden2 
        #and the output.
        self.out = nn.Linear(hidden2, out_features)
    
    #class methods/functions-->build in forward propagation into the class   
    def forward(self, x):
        #apply activation functions-->relu (from torch.nn.functional as F)
        x = F.relu(self.layer_1_connection(x))
        x = F.relu(self.layer_2_connection(x))
        x = self.out(x)
        return x

# %%
torch.manual_seed(42)

#create instance of model
    # by making the variable 'ann' equal to the class, it is automatically passing in the NN created 
    # within the class above
ann = ANN_Model()

# %%
#loss function
loss_function = nn.CrossEntropyLoss()

#optimizer--a way to improve the model on top of applying activation function, loss functions 
# pass in a learning rate-- you wouldnt want it to learn too quickly cuz that would make haste-y decisions
optimizer = torch.optim.Adam(ann.parameters(),lr=0.02)

# %%
#run model through multiple epochs/iterations
#this is how we will record the loss

final_loss = []
n_epochs = 500
for epoch in range(n_epochs):
    y_pred = ann.forward(X_train) #ann, name of model, forward propagate the training data
    loss = loss_function(y_pred, y_train)
    final_loss.append(loss)
    
    if epoch % 10 == 1: #for every 10 iterations...
        print(f'Epoch number: {epoch} with loss: {loss}')
    
    #Impliment optimizer with gradient decent
    # .zero_grad() --> allows us to work on just imporving our loss function using backward 
    #propagation w/o having forward rpopagation interfere 
    optimizer.zero_grad() #zero the gradient before running backwards propagation so we are starting fresh
    loss.backward() 
    optimizer.step() #perform one optimization step each epoch

#as we can see, there is lower loss as we increase the iterations
# Out:
# Epoch number: 1 with loss: 0.5679716467857361
# Epoch number: 11 with loss: 0.07899633795022964
# Epoch number: 21 with loss: 0.00504554808139801
# Epoch number: 31 with loss: 6.175383896334097e-05
# Epoch number: 41 with loss: 7.432846814481309e-06
# Epoch number: 51 with loss: 3.114694436590071e-06
# Epoch number: 61 with loss: 1.2545028766908217e-06
# Epoch number: 71 with loss: 7.307621103791462e-07
# Epoch number: 81 with loss: 5.438164407678414e-07
# Epoch number: 91 with loss: 4.4655860165221384e-07
# Epoch number: 101 with loss: 3.8411658920267655e-07
# Epoch number: 111 with loss: 3.390824758753297e-07
# Epoch number: 121 with loss: 3.054014712233766e-07
# Epoch number: 131 with loss: 2.792892246361589e-07
# Epoch number: 141 with loss: 2.5582602347640204e-07
# Epoch number: 151 with loss: 2.3690404304943513e-07
# Epoch number: 161 with loss: 2.2214491934846592e-07
# Epoch number: 171 with loss: 2.077642022868531e-07
# Epoch number: 181 with loss: 1.960325448635558e-07
# Epoch number: 191 with loss: 1.8543624946687487e-07
# Epoch number: 201 with loss: 1.7483989722677507e-07
# Epoch number: 211 with loss: 1.6575732786350272e-07
# Epoch number: 221 with loss: 1.570531935612962e-07
# Epoch number: 231 with loss: 1.5099814731911465e-07
# Epoch number: 241 with loss: 1.4342934662181506e-07
# Epoch number: 251 with loss: 1.3699585110771295e-07
# Epoch number: 261 with loss: 1.3245455932064942e-07
# Epoch number: 271 with loss: 1.2602106380654732e-07
# Epoch number: 281 with loss: 1.2223665635247016e-07
# Epoch number: 291 with loss: 1.1656004517135443e-07
# Epoch number: 301 with loss: 1.1277560929556785e-07
# Epoch number: 311 with loss: 1.0899120894691805e-07
# Epoch number: 321 with loss: 1.0596368582582727e-07
# Epoch number: 331 with loss: 1.0180083620525693e-07
# Epoch number: 341 with loss: 9.953019031172516e-08
# Epoch number: 351 with loss: 9.57457686467933e-08
# Epoch number: 361 with loss: 9.271824552570251e-08
# Epoch number: 371 with loss: 8.8933830966198e-08
# Epoch number: 381 with loss: 8.704163434458678e-08
# Epoch number: 391 with loss: 8.439253917913447e-08
# Epoch number: 401 with loss: 8.250032834666854e-08
# Epoch number: 411 with loss: 8.06081175142026e-08
# Epoch number: 421 with loss: 7.833746451524348e-08
# Epoch number: 431 with loss: 7.53099413941527e-08
# Epoch number: 441 with loss: 7.379617272817995e-08
# Epoch number: 451 with loss: 7.22824040622072e-08
# Epoch number: 461 with loss: 7.076864250166182e-08
# Epoch number: 471 with loss: 7.001175106324808e-08
# Epoch number: 481 with loss: 6.774110516971632e-08
# Epoch number: 491 with loss: 6.69842279421573e-08

# %%
#store predictions in list
y_pred = []

with torch.no_grad(): #start with zero gradiation and iterate thru the below for loop...
    for i, data in enumerate(X_test): # i --> keep track of index, enumerate thru test set
        prediction = ann(data)
        y_pred.append(prediction.argmax()) #look up argmax (Alexis did not have explanation)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79        74
#            1       0.76      0.69      0.72        61
#
#     accuracy                           0.76       135
#    macro avg       0.76      0.76      0.76       135
# weighted avg       0.76      0.76      0.76       135

# %% [markdown]
# #### 6.	Compare the performance of the neural networks to the other model you created. Which performed better? Why do you think that is?

# %% [markdown]
# # TROUBLESHOOTING STEPS:
#
# # DONE: NEXT STEP--> .values
#
# # DONE: SKIP PREPROCESSING STEPS 7-8
#
# # DONE: (just keep standard scalar)
#
# # NEXT STEP--> GO BACK TO ONE HOT ENCODING
